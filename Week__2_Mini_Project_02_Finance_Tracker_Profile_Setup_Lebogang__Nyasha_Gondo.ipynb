# %% [markdown]
# <a href="https://colab.research.google.com/github/leboganggondopython7278/Lab-Tickets/blob/main/Week__2_Mini_Project_02_Finance_Tracker_Profile_Setup_Lebogang__Nyasha_Gondo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mini Project 02: Finance Tracker Profile Setup
#
# In this project, you will build the first component of our semester-long Personal Finance Tracker: the user profile setup. This project collates many of the exercises from this week’s activities. This is intentional—by combining these exercises, you can reflect on your progress and see how well you’re following the industry best practices we espouse. These practices include:
#
# - **Meaningful Notebook Naming:** Give your notebook a clear, descriptive name (e.g., `finance_tracker_profile_setup.ipynb`).
# - **Frequent Saves & Version Control:** Save your work often and use descriptive commit messages when uploading to GitHub.
# - **Descriptive Variable Names:** Use names like `user_name`, `theme_color`, etc., to clearly convey their purpose.
# - **Code Comments & Documentation:** Use text cells and inline comments to document your thought process.
# - **Critical Use of AI:** Ask follow-up questions if anything is unclear, and verify that AI suggestions align with the basics you’ve learnt (i.e., using input(), print(), basic data types, and variables).
#
# > **Tip:** Review these best practices periodically during the project to reinforce good coding habits.
#
# Let's get started!

# %% [raw]
# ---
#
# ## Project Overview and Instructions
#
# In this project, you'll create a program that:
# 1. **Collects User Profile Information:**
#    Ask for the user's name, preferred app theme color, primary currency, and a main savings goal.
# 2. **Displays a Personalised Welcome Message:**
#    Outputs a clear summary message using the collected data to confirm the profile setup.
# 3. **Follows Industry Best Practices:**
#    Emphasises meaningful variable names, proper documentation, and good version control.
#
# **Project Steps:**
# 1. **State the Problem**
# 2. **Describe Input and Output**
# 3. **Work the Problem by Hand**
# 4. **Develop an Algorithm (Pseudocode)**
# 5. **Write the Code**
# 6. **Reflect on Best Practices & Use AI to Verify**
#
# > **Note:** Use this project as an opportunity to both practise coding and refine your professional development skills.
#
# ---

# %% [markdown]
# ## Step 1 – State the Problem
#
#
# """
# Goal: Build a program that creates a user profile for a
# personal finance tracker by collecting initial settings
# and displaying a personalized welcome message.
#
# I used ChatGPT to help me restate my problem:
# "Create a Finance Tracker Profile Setup program that uses
# input() to collect a user's name, preferred theme color,
# primary currency, and main savings goal. Then use print()
# and variables to display a personalized welcome message
# summarizing their profile settings."
#
# Data to Gather:
# - user_name: The name of the user
# - theme_color: Preferred app theme color
# - primary_currency: User's primary currency
# - main_savings_goal: User's main savings goal
# """
#
# print("Step 1 Complete: Problem defined! ✅")

# %% [markdown]
# Step 2 - Describe Input and Output
#
# Inputs:
# - user_name (string): The name of the user
# - theme_color (string): Preferred app theme color
# - primary_currency (string): User's primary currency
# - main_savings_goal (string): User's main savings goal
#
# Expected Output:
# "Welcome to your Personal Finance Tracker, Sky!
# Your profile is ready. The app will use a leafy green
# theme and all amounts will be in USD. Let's start
# working towards your goal of saving for a house!"
#
# Tip Reflection:
# Mapping my inputs to the expected output helped me
# visualise how each variable connects to the final
# message before writing any code.
#
# AI Usage Tip:
# I asked ChatGPT to suggest creative ways to format
# the welcome message. I verified the suggestions only
# used input(), print() and basic variables which
# aligns with what I have learned so far.

# %% [raw]
# ---
#
# ## Step 2 – Describe Input and Output
#
# **Inputs:**
# - `user_name` (string)
# - `theme_color` (string)
# - `primary_currency` (string)
# - `main_savings_goal` (string)
#
# **Expected Output:**
# A message like:
# > "Welcome to your Personal Finance Tracker, [user_name]! Your profile is ready. The app will use a [theme_color] theme and all amounts will be in [primary_currency]. Let's start working towards your goal of saving for a [main_savings_goal]!"
#
# > **Tip:** Mapping your inputs to the expected output helps you visualise the overall flow of your program.
#
# > **AI Usage Tip:**
# > Ask, "What are some creative ways to format this welcome message for a finance app using only the basics?" and verify that the suggestions adhere to input(), print(), and basic variables.

# %% [markdown]
# ## Step 3 – Work the Problem by Hand
# Step 3 - Work the Problem by Hand
#
# Scenario 1:
# user_name = "Sky"
# theme_color = "leafy green"
# primary_currency = "USD"
# main_savings_goal = "house"
#
# Expected Output:
# "Welcome to your Personal Finance Tracker, Sky! Your
# profile is ready. The app will use a leafy green theme
# and all amounts will be in USD. Let's start working
# towards your goal of saving for a house!"
#
# Scenario 2:
# user_name = "Lebogang"
# theme_color = "dark blue"
# primary_currency = "USD"
# main_savings_goal = "car"
#
# Expected Output:
# "Welcome to your Personal Finance Tracker, Lebogang!
# Your profile is ready. The app will use a dark blue
# theme and all amounts will be in USD. Let's start
# working towards your goal of saving for a car!"

# %% [markdown]
# ---
#
# ## Step 4 – Develop an Algorithm (Pseudocode)
#
# Step 4 - Develop an Algorithm (Pseudocode)
#
# 1. Start the program
# 2. Prompt the user for their name and store it
# 3. Prompt for their preferred theme color and store it
# 4. Prompt for their primary currency and store it
# 5. Prompt for their main savings goal and store it
# 6. Construct a personalized welcome message by combining
#    user_name, theme_color, primary_currency and
#    main_savings_goal into one summary string
# 7. Print the summary message
# 8. End the program
#
# Tip Reflection:
# Writing pseudocode before coding helped me think through
# the logical steps without worrying about Python syntax.
# It made writing the actual code much faster and clearer.
#
# AI Usage Tip:
# I asked ChatGPT: "Can you review my pseudocode for a
# Finance Tracker Profile Setup program and suggest
# improvements?"
#
# ChatGPT confirmed my steps were logical and suggested
# adding a construct step before printing. I verified
# the suggestions stayed within input(), print() and
# basic variables which aligns with what I have learned.
#
# ---
#
# ## Step 5 – Write the Code
#
# Translate your pseudocode into Python code. Below is one example solution:

# %%
# Import datetime to timestamp your work
from datetime import datetime

# Collect user information for their financial profile
user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday) ")

# Construct the personalized welcome message
summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " + \
           "The app will use a " + theme_color + " theme and all amounts will be in " + \
           primary_currency + ". Let's start working towards your goal of saving for a " + \
           main_savings_goal + "!")

# Display the summary message
print(summary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-166/1262083418.py in <cell line: 0>()
#       3
#       4 # Collect user information for their financial profile
# ----> 5 user_name = input("What is your name? ")
#       6 theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
#       7 primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
from datetime import datetime

user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? ")
primary_currency = input("What is your primary currency? (e.g., USD, AUD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? ")
secondary_savings_goal = input("What is your secondary savings goal? ")

summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " +
"The app will use a " + theme_color + " theme and all amounts will be in " +
primary_currency + ". Let's start working towards your goal of saving for a " +
main_savings_goal + "! Your secondary goal is saving for a " +
secondary_savings_goal + "!")

print(summary)
# Out:
# What is your name? Sky
# What color would you like for your app theme? leafy green
# What is your primary currency? (e.g., USD, AUD, EUR) USD
# What is one big savings goal you have? house
# What is your secondary savings goal? car
# Welcome to your Personal Finance Tracker, Sky! Your profile is ready. The app will use a leafy green theme and all amounts will be in USD. Let's start working towards your goal of saving for a house! Your secondary goal is saving for a car!

# %% [markdown]
# ---
#
# ## 📋 Evidence Package for Lab Exit Ticket
#
# Complete the following evidence package to document your work and reflect on the process. This will be checked at the start of the next lab.

# %%
evidence_package = {
    "timestamp": "2026-03-01 21:00:00",
    "student_name": "Lebogang Nyasha Gondo",
    "project_context": "This project involved creating the initial user profile for a personal finance tracker.",
    "ai_tool_used": "ChatGPT",
    "ai_assistance_summary": "I used ChatGPT to review my pseudocode and suggest ways to format the welcome message.",
    "best_practice_reflection": "Using descriptive variable names like user_name made my code easier to read.",
    "key_learning": "Working the problem by hand first made writing the actual code much faster."
}

print("="*50)
print("EVIDENCE PACKAGE SUBMISSION")
print("="*50)
for key, value in evidence_package.items():
    print(f"{key}: {value}")
print("="*50)
# Out:
# ...
# EVIDENCE PACKAGE SUBMISSION
# ...
# timestamp: 2026-03-01 21:00:00
# student_name: Lebogang Nyasha Gondo
# project_context: This project involved creating the initial user profile for a personal finance tracker.
# ai_tool_used: ChatGPT
# ai_assistance_summary: I used ChatGPT to review my pseudocode and suggest ways to format the welcome message.
# best_practice_reflection: Using descriptive variable names like user_name made my code easier to read.
# key_learning: Working the problem by hand first made writing the actual code much faster.
# ...

# %% [markdown]
# ---
#
# ## Reflection on Industry Best Practices
#
# Reflection on Industry Best Practices
#
# 1. How did using descriptive variable names and comments
# improve your code?
# Using names like user_name, theme_color and primary_currency
# made my code easy to read and understand. Instead of using
# short names like x or c, descriptive names clearly showed
# what each variable was storing. Comments also helped me
# remember what each section of code was doing.
#
# 2. Did you save your work frequently and use meaningful
# commit messages on GitHub?
# Yes I saved my work frequently. I used commit messages like
# "Add Week 2 Finance Tracker Profile" so that anyone reading
# my GitHub could clearly understand what changes were made
# and why.
#
# 3. How did documenting your thought process help you
# understand your solution better?
# Writing pseudocode and working the problem by hand first
# helped me think through the steps clearly before writing
# any code. This made the actual coding much easier and faster
# because I already had a clear plan.
#
# AI Usage Tip:
# I asked ChatGPT: "Can you suggest improvements to my
# project documentation and commit message examples based
# on industry best practices for a finance app setup?"
#
# ChatGPT suggested:
# - Use clear descriptive commit messages
# - Add inline comments to explain each section
# - Use meaningful variable names throughout
#
# I verified these suggestions align with input(), print()
# and basic variables which is what I have learned so far.
#
#
# ---
#
# ## Final Reflection and Next Steps
#
# - **Reflect:**
#   Completing this project helped me see how all the
# exercises from this week connect together. Combining
# inputs, variables and print statements into one
# complete program showed me how far I have progressed.
# - **Experiment:**
# I experimented by adding a secondary savings goal
# input to make the tracker more detailed. This gave
# the user the ability to track two savings goals
# at the same time making the program more useful.
#
# - **Share:**
#   I have shared my project on GitHub with clear commit messages and will continue using AI tools critically
# to support my learning while always verifying
# suggestions align with what I have learned.
# - **Continue Using AI:**
#   I will continue using AI tools like ChatGPT to clarify
# doubts and review my work. I will always verify that
# suggestions align with what I have learned which means
# only using input(), print() and basic variables.
#
#
# > **Final Note:**
# > The practices developed in this project such as
# descriptive variable names, pseudocode planning and
# critical AI usage are good habits that will help me
# write clean and maintainable code as I grow as a
# software developer.
#
# ---
#
# Enjoy building this first step of your Personal Finance Tracker while practising these best practices!
